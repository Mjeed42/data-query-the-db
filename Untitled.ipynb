# %%
fruits = ['apple', 'banana', 'orange', 'strawberries', 'melon', 'pear']
uppercase_fruits = [ i for i in fruits if i[0] > 'n' uppercase_fruits.append(i.upper()) ]

print(uppercase_fruits)
# Out:
#   Cell In [33], line 2
#     uppercase_fruits = [ i for i in fruits if i[0] > 'n' uppercase_fruits.append(i.upper()) ]
#                                                          ^
# SyntaxError: invalid syntax
